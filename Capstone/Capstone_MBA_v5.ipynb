# %% [markdown]
# <a href="https://colab.research.google.com/github/dgalian/FTW_B7/blob/main/Capstone/Capstone_MBA_v5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Using Market Basket Analysis to determine the typical combinations of ICD Categories per Claim**

# %% [markdown]
# # Import libraries and load dataset

# %%
# Importing
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load claims breakdown by diagnosis
clm_icd = pd.read_csv('/content/CLM Breakdown csv.csv')

# %%
# Load ICD table to get ICD category
icd_table = pd.read_excel('/content/icd_table.xlsx')

# %% [markdown]
# # Data Prep
# Profiling, Cleaning

# %%
clm_icd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382438 entries, 0 to 382437
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   cbdcode        382438 non-null  int64
#  1   claimcode      382438 non-null  int64
#  2   icdno          382438 non-null  int64
#  3   doctorcode     382438 non-null  int64
#  4   cptno          382438 non-null  int64
#  5   sacode         382438 non-null  int64
#  6   UNIT AMT       382438 non-null  float64
#  7   QTY            382438 non-null  float64
#  8   INCURRED AMT   382438 non-null  float64
#  9   HOSP BILL AMT  382438 non-null  float64
#  10  COVERED AMT    382438 non-null  float64
#  11  BILL TO        382438 non-null  object
# dtypes: float64(5), int64(6), object(1)
# memory usage: 35.0+ MB

# %%
# Check number of claims
clm_icd['claimcode'].nunique()
# Out:
# 166993

# %%
icd_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4343 entries, 0 to 4342
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   icdno        4343 non-null   int64
#  1   icdcategory  4343 non-null   int64
#  2   icdgroup     4343 non-null   int64
#  3   ICD CODE     4343 non-null   object
#  4   ICD DISEASE  4343 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 169.8+ KB

# %%
# Creating basket of claims by merging claims table and icd category table
claims = pd.merge(clm_icd, icd_table, on='icdno', how='left')

# %%
claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 382438 entries, 0 to 382437
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   cbdcode        382438 non-null  int64
#  1   claimcode      382438 non-null  int64
#  2   icdno          382438 non-null  int64
#  3   doctorcode     382438 non-null  int64
#  4   cptno          382438 non-null  int64
#  5   sacode         382438 non-null  int64
#  6   UNIT AMT       382438 non-null  float64
#  7   QTY            382438 non-null  float64
#  8   INCURRED AMT   382438 non-null  float64
#  9   HOSP BILL AMT  382438 non-null  float64
#  10  COVERED AMT    382438 non-null  float64
#  11  BILL TO        382438 non-null  object
#  12  icdcategory    382355 non-null  float64
#  13  icdgroup       382355 non-null  float64
#  14  ICD CODE       382355 non-null  object
#  15  ICD DISEASE    382355 non-null  object
# dtypes: float64(7), int64(6), object(3)
# memory usage: 49.6+ MB

# %%
claims.isnull().sum()
# Out:
# cbdcode           0
# claimcode         0
# icdno             0
# doctorcode        0
# cptno             0
# sacode            0
# UNIT AMT          0
# QTY               0
# INCURRED AMT      0
# HOSP BILL AMT     0
# COVERED AMT       0
# BILL TO           0
# icdcategory      83
# icdgroup         83
# ICD CODE         83
# ICD DISEASE      83
# dtype: int64

# %%
null_icd = claims[claims['icdcategory'].isnull()]
null_icd['claimcode'].nunique()
# Out:
# 46

# %% [markdown]
# **46 claims do not have an ICD category**

# %%
# Drop null values
claims = claims.dropna()
claims.isnull().sum()
# Out:
# cbdcode          0
# claimcode        0
# icdno            0
# doctorcode       0
# cptno            0
# sacode           0
# UNIT AMT         0
# QTY              0
# INCURRED AMT     0
# HOSP BILL AMT    0
# COVERED AMT      0
# BILL TO          0
# icdcategory      0
# icdgroup         0
# ICD CODE         0
# ICD DISEASE      0
# dtype: int64

# %%
# Convert Claim code and ICD Category into categorical data
claims['claimcode'] = claims['claimcode'].astype(str)
claims['icdcategory'] = claims['icdcategory'].astype(int).astype(str)
claims['sacode'] = claims['sacode'].astype(int).astype(str)

# %%
# Drop other columns
claims = claims[['claimcode','icdno','icdcategory','ICD CODE','ICD DISEASE','sacode']]
claims.head()
# Out:
#   claimcode  icdno icdcategory ICD CODE  \
# 0    203746   6127          84    G90.0
# 1    203913  40054         261      W55
# 2    203913  40054         261      W55
# 3    203913  40054         261      W55
# 4    203913  40054         261      W55
#
#                                   ICD DISEASE sacode
# 0  Idiopathic peripheral autonomic neuropathy   3718
# 1                  Contact with other mammals   3747
# 2                  Contact with other mammals   3750
# 3                  Contact with other mammals   3953
# 4                  Contact with other mammals   3954

# %%
# Check claim with duplicate ICD category 
claims[claims['claimcode']=='203913']
# Out:
#   claimcode  icdno icdcategory ICD CODE                 ICD DISEASE sacode
# 1    203913  40054         261      W55  Contact with other mammals   3747
# 2    203913  40054         261      W55  Contact with other mammals   3750
# 3    203913  40054         261      W55  Contact with other mammals   3953
# 4    203913  40054         261      W55  Contact with other mammals   3954
# 5    203913  40054         261      W55  Contact with other mammals   3843
# 6    203913  40054         261      W55  Contact with other mammals   3726

# %%
# Check number of unique ICD categories in claims
claims['icdcategory'].nunique()
# Out:
# 241

# %%
241/290
# Out:
# 0.8310344827586207

# %% [markdown]
# **241 out of 290 or 83% of ICD categories are present in the claims.**

# %%
# Removing duplicate ICD categories in claims, since we are only looking at the occurance of the ICD category per claim
claims['claims_icd'] = claims[['claimcode', 'icdcategory']].agg('_'.join, axis=1)
claims_icd = claims.drop_duplicates(subset='claims_icd')

# %%
claims['icdcategory'].nunique()
# Out:
# 241

# %%
claims_icd[claims_icd['icdcategory']=='0']
# Out:
#        claimcode  icdno icdcategory ICD CODE                 ICD DISEASE  \
# 120       208601  77693           0    A09.1    AGE WITH MOD./MARKED DHN
# 723       212928  77693           0    A09.1    AGE WITH MOD./MARKED DHN
# 1068      213902  77689           0        1         LACK OF DOCUMENTS
# 1358      214385  77771           0    I10.0                 HPN STAGE I
# 1516      214739  77695           0    A09.3    AGE WITH NO SIGNS OF DHN
# ...          ...    ...         ...      ...                         ...
# 382205    602217  77782           0    U07.1  COVID-19, virus identified
# 382208    602620  77771           0    I10.0                 HPN STAGE I
# 382233    607092  77782           0    U07.1  COVID-19, virus identified
# 382308    616034  77771           0    I10.0                 HPN STAGE I
# 382370    631106  77782           0    U07.1  COVID-19, virus identified
#
#        sacode claims_icd
# 120      3812   208601_0
# 723      3747   212928_0
# 1068     3718   213902_0
# 1358     3718   214385_0
# 1516     3747   214739_0
# ...       ...        ...
# 382205   3718   602217_0
# 382208   3816   602620_0
# 382233   3747   607092_0
# 382308   3718   616034_0
# 382370   3718   631106_0
#
# [5813 rows x 7 columns]

# %%
# Dropping ICD Category 0
claims_icd = claims_icd[claims_icd.icdcategory != '0']
claims_icd[claims_icd['icdcategory']=='0']
# Out:
# Empty DataFrame
# Columns: [claimcode, icdno, icdcategory, ICD CODE, ICD DISEASE, sacode, claims_icd]
# Index: []

# %%
# Checking number of ICD categories per claim
claims_icd['claimcode'].value_counts().sort_values(ascending=False)
# Out:
# 305146    10
# 309069    10
# 328555    10
# 355547     9
# 377387     9
#           ..
# 453359     1
# 453361     1
# 453363     1
# 453376     1
# 658022     1
# Name: claimcode, Length: 161973, dtype: int64

# %%
claims_icd[claims_icd['claimcode']=='328555']
# Out:
#        claimcode  icdno icdcategory ICD CODE  \
# 201183    328555  12785         130    K76.0
# 201184    328555  46010         158    M81.9
# 201186    328555  25106         216    R80.9
# 201188    328555   3857          54      E11
# 201189    328555  14648         144    M06.9
# 201190    328555   4467          61    E87.8
# 201191    328555   3639          53    E03.9
# 201192    328555  20895         167    N20.9
# 201193    328555  10140         105    I25.1
# 201195    328555  10341         107    I49.9
#
#                                               ICD DISEASE sacode  claims_icd
# 201183  Fatty (change of) liver, not elsewhere classified   3807  328555_130
# 201184                          Osteoporosis, unspecified   3803  328555_158
# 201186                           Proteinuria, unspecified   3808  328555_216
# 201188                           Type 2 diabetes mellitus   3803   328555_54
# 201189                  Rheumatoid arthritis, unspecified   3800  328555_144
# 201190  Other disorders of electrolyte and fluid balan...   3803   328555_61
# 201191                        Hypothyroidism, unspecified   3806   328555_53
# 201192                      Urinary calculus, unspecified   3978  328555_167
# 201193  Atherosclerotic heart disease of native corona...   3853  328555_105
# 201195                    Cardiac arrhythmia, unspecified   3816  328555_107

# %%
# Considering only claims with 2 or more ICD categories
claims_icdcombo = claims_icd.groupby('claimcode').filter(lambda x : x['claimcode'].shape[0]>1)
claims_icdcombo['claimcode'].value_counts().sum()
# Out:
# 37304

# %%
claims_icdcombo.head()
# Out:
#      claimcode  icdno icdcategory ICD CODE  \
# 7815    220945  11745         113    J18.9
# 7822    220945  21009         169    N39.0
# 7828    220946  76619         104    I10.9
# 7829    220946   3857          54      E11
# 7831    220946  11745         113    J18.9
#
#                                          ICD DISEASE sacode  claims_icd
# 7815                 Pneumonia, unspecified organism   1196  220945_113
# 7822     Urinary tract infection, site not specified   3812  220945_169
# 7828  Essential Hypertension; malignant hypertension   3952  220946_104
# 7829                        Type 2 diabetes mellitus   4020   220946_54
# 7831                 Pneumonia, unspecified organism   3712  220946_113

# %%
37304/166993
# Out:
# 0.22338660901953974

# %% [markdown]
# **37,304 out of 166,993 or 22% of the claims has 2 or more ICD categories.**

# %% [markdown]
# ## Preparing Transaction List

# %%
# Get list ICD Categories by Claim number
transactions = claims_icdcombo.groupby('claimcode').agg(lambda col: ','.join(col)).reset_index()
transactions.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/generic.py:303: FutureWarning: Dropping invalid columns in SeriesGroupBy.agg is deprecated. In a future version, a TypeError will be raised. Before calling .agg, select only columns which should be valid for the aggregating function.
#   results[key] = self.aggregate(func)
#   claimcode icdcategory           ICD CODE  \
# 0    220945     113,169        J18.9,N39.0
# 1    220946  104,54,113    I10.9,E11,J18.9
# 2    230470   53,54,105    E03.9,E11,I25.0
# 3    232051  169,53,104  N39.0,E05.9,I11.9
# 4    251715      54,104          E11,I10.9
#
#                                          ICD DISEASE          sacode  \
# 0  Pneumonia, unspecified organism,Urinary tract ...       1196,3812
# 1  Essential Hypertension; malignant hypertension...  3952,4020,3712
# 2  Hypothyroidism, unspecified,Type 2 diabetes me...  3806,3808,3979
# 3  Urinary tract infection, site not specified,Th...  3812,3806,3816
# 4  Type 2 diabetes mellitus,Essential Hypertensio...       3803,3821
#
#                         claims_icd
# 0            220945_113,220945_169
# 1  220946_104,220946_54,220946_113
# 2   230470_53,230470_54,230470_105
# 3  232051_169,232051_53,232051_104
# 4             251715_54,251715_104

# %%
transactions['icd'] = transactions['icdcategory'].apply(lambda t: t.split(','))
transactions = transactions['icd']
transactions.head()
# Out:
# 0        [113, 169]
# 1    [104, 54, 113]
# 2     [53, 54, 105]
# 3    [169, 53, 104]
# 4         [54, 104]
# Name: icd, dtype: object

# %%
transaction_list = list(transactions)
transaction_list[:30]
# Out:
# [['113', '169'],
#  ['104', '54', '113'],
#  ['53', '54', '105'],
#  ['169', '53', '104'],
#  ['54', '104'],
#  ['97', '100'],
#  ['166', '104'],
#  ['61', '131'],
#  ['104', '55'],
#  ['104', '54'],
#  ['15', '169'],
#  ['113', '55', '53'],
#  ['104', '61'],
#  ['105', '54'],
#  ['108', '170'],
#  ['284', '139'],
#  ['48', '104'],
#  ['104', '55'],
#  ['53', '55'],
#  ['104', '53'],
#  ['104', '61'],
#  ['169', '112'],
#  ['108', '104'],
#  ['104', '55'],
#  ['130', '21', '54', '42', '105', '171', '124'],
#  ['112', '105'],
#  ['39', '171'],
#  ['61', '53', '173', '131', '214', '168'],
#  ['53', '105', '152', '61'],
#  ['152', '105']]

# %% [markdown]
# ## One Hot Encoding

# %%
# Import the transaction encoder function from mlxtend
from mlxtend.preprocessing import TransactionEncoder

# Instantiate transaction encoder and identify unique items in transactions
encoder = TransactionEncoder().fit(transaction_list)

# One-hot encode transactions
onehot = encoder.transform(transaction_list)

# Convert one-hot encoded data to DataFrame
onehot = pd.DataFrame(onehot, columns = encoder.columns_)
onehot
# Out:
#            1     10    100    102    103    104    105    106    107    108  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False   True  False  False  False  False
# 2      False  False  False  False  False  False   True  False  False  False
# 3      False  False  False  False  False   True  False  False  False  False
# 4      False  False  False  False  False   True  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 13873  False  False  False  False  False  False   True  False  False  False
# 13874  False  False  False  False  False   True  False  False  False   True
# 13875  False  False  False  False  False  False  False  False  False  False
# 13876  False  False  False  False  False  False  False  False  False  False
# 13877  False  False  False  False  False  False   True  False  False   True
#
#        ...     87     88     89     90     91     93     95     97     98  \
# 0      ...  False  False  False  False  False  False  False  False  False
# 1      ...  False  False  False  False  False  False  False  False  False
# 2      ...  False  False  False  False  False  False  False  False  False
# 3      ...  False  False  False  False  False  False  False  False  False
# 4      ...  False  False  False  False  False  False  False  False  False
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 13873  ...  False  False  False  False  False  False  False  False  False
# 13874  ...  False  False  False  False  False  False  False  False  False
# 13875  ...  False  False  False  False  False  False  False  False  False
# 13876  ...  False  False  False  False  False  False  False  False  False
# 13877  ...  False  False  False  False  False  False  False  False  False
#
#           99
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 13873  False
# 13874  False
# 13875  False
# 13876  False
# 13877  False
#
# [13878 rows x 173 columns]

# %% [markdown]
# # MBA - Diagnosis that are claimed together

# %% [markdown]
# ##Apriori

# %%
# Choose max_len
claims_icdcombo['claimcode'].value_counts().describe()
# Out:
# count    13878.000000
# mean         2.687995
# std          1.018211
# min          2.000000
# 25%          2.000000
# 50%          2.000000
# 75%          3.000000
# max         10.000000
# Name: claimcode, dtype: float64

# %%
icd_count = pd.DataFrame(claims_icdcombo['claimcode'].value_counts())
plt.figure(figsize=(8,6))
ax = sns.countplot('claimcode', data=icd_count)
ax.set_xlabel('Number of ICD category present in claim')
ax.set_ylabel('Number of Claims')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Number of Claims')

# %%
plt.figure(figsize=(5,8))
ax = sns.boxplot(y='claimcode', data=icd_count)
ax.set_ylabel('Number of ICD category present in claim')
# Out:
# Text(0, 0.5, 'Number of ICD category present in claim')

# %% [markdown]
# We will choose max length of 3.

# %%
from mlxtend.frequent_patterns import apriori

# Getting all combinations of item sets
frequent_itemsets = apriori(onehot, 
                            min_support = 0, 
                            max_len = 3, 
                            use_colnames = True).sort_values('support',ascending=False)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets.head()
# Out:
#        support   itemsets  length
# 147   0.428376       (61)       1
# 5     0.408632      (104)       1
# 141   0.236922       (54)       1
# 142   0.225897       (55)       1
# 1164  0.153480  (61, 104)       2

# %% [markdown]
# **Min support is 0 for frequent_itemsets**

# %% [markdown]
# ##Apriori results pruning

# %% [markdown]
# ### Association Rule #1 - Confidence

# %%
from mlxtend.frequent_patterns import association_rules

# Get frequent item sets with minimum support 0.001
frequent_itemsets1 = apriori(onehot, 
                            min_support = 0.001, 
                            max_len = 3, 
                            use_colnames = True).sort_values('support',ascending=False)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

rules_1 = association_rules(frequent_itemsets1, 
                          metric = "confidence", 
                         	min_threshold = 0.65).sort_values('confidence',ascending=False)
rules_1
# Out:
#    antecedents consequents  antecedent support  consequent support   support  \
# 20  (171, 112)        (54)            0.001153            0.236922  0.001009
# 7    (215, 48)        (61)            0.003963            0.428376  0.003315
# 21  (116, 130)        (61)            0.001225            0.428376  0.001009
# 13  (144, 215)        (61)            0.002018            0.428376  0.001657
# 14  (168, 130)        (61)            0.002018            0.428376  0.001585
# 1   (215, 130)        (61)            0.016069            0.428376  0.012610
# 3   (169, 215)        (61)            0.006989            0.428376  0.005476
# 11  (215, 131)        (61)            0.002882            0.428376  0.002234
# 4   (170, 215)        (61)            0.006197            0.428376  0.004684
# 9   (167, 215)        (61)            0.004468            0.428376  0.003315
# 22    (1, 112)       (105)            0.001369            0.099222  0.001009
# 10  (215, 107)        (61)            0.003170            0.428376  0.002306
# 0        (215)        (61)            0.081640            0.428376  0.059375
# 15  (167, 112)        (61)            0.002234            0.428376  0.001585
# 5   (112, 130)        (61)            0.006053            0.428376  0.004251
# 18   (15, 130)       (169)            0.001657            0.128116  0.001153
# 17  (170, 112)       (130)            0.002090            0.149733  0.001441
# 19   (116, 54)        (61)            0.001585            0.428376  0.001081
# 2   (169, 130)        (61)            0.016069            0.428376  0.010953
# 16  (215, 112)        (61)            0.002234            0.428376  0.001513
# 12  (166, 130)        (61)            0.002810            0.428376  0.001873
# 8   (215, 105)        (61)            0.004972            0.428376  0.003315
# 6    (54, 112)        (61)            0.005620            0.428376  0.003747
#
#     confidence      lift  leverage  conviction
# 20    0.875000  3.693203  0.000736    6.104626
# 7     0.836364  1.952406  0.001617    3.493259
# 21    0.823529  1.922446  0.000484    3.239204
# 13    0.821429  1.917542  0.000793    3.201095
# 14    0.785714  1.834170  0.000721    2.667579
# 1     0.784753  1.831927  0.005726    2.655671
# 3     0.783505  1.829013  0.002482    2.640359
# 11    0.775000  1.809159  0.000999    2.540552
# 4     0.755814  1.764371  0.002029    2.340937
# 9     0.741935  1.731973  0.001401    2.215044
# 22    0.736842  7.426213  0.000873    3.422957
# 10    0.727273  1.697744  0.000948    2.095955
# 0     0.727273  1.697744  0.024402    2.095955
# 15    0.709677  1.656670  0.000628    1.968928
# 5     0.702381  1.639637  0.001658    1.920657
# 18    0.695652  5.429843  0.000941    2.864760
# 17    0.689655  4.605888  0.001128    2.739748
# 19    0.681818  1.591635  0.000402    1.796533
# 2     0.681614  1.591160  0.004069    1.795383
# 16    0.677419  1.581367  0.000556    1.772035
# 12    0.666667  1.556266  0.000670    1.714872
# 8     0.666667  1.556266  0.001185    1.714872
# 6     0.666667  1.556266  0.001339    1.714872

# %%
# Checking ICD Category #61
icd_categories = pd.read_csv('/content/icd_category_categorydes.csv')
icd_categories[icd_categories['icdcategory']==61]
# Out:
#     icdcategory                   ICD CATEGORY
# 60           61  Metabolic disorders (E70-E88)

# %% [markdown]
# Metabolic disorders is a frequent consequent ICD

# %% [markdown]
# ### Association Rule #2 - Zhang (trial from DataCamp)

# %% [markdown]
# **Zhang's rule**

# %%
# Define a new zhang's metric function
def zhangs_rule(rules):
	PAB = rules['support'].copy()
	PA = rules['antecedent support'].copy()
	PB = rules['consequent support'].copy()
	NUMERATOR = PAB - PA*PB
	DENOMINATOR = np.max((PAB*(1-PA).values,PA*(PB-PAB).values), axis = 0)
	return NUMERATOR / DENOMINATOR

# %%
# Generate the initial set of rules using a minimum lift of 1.00 on frequent_itemsets (all combinations)
rules_2 = association_rules(frequent_itemsets, metric = "lift", min_threshold = 1)

# Set antecedent support to 0.01
rules_2 = rules_2[rules_2['antecedent support'] > 0.01]

# Set consequent support to 0.01
rules_2 = rules_2[rules_2['consequent support'] > 0.01]

# Compute Zhang's rule
rules_2['zhang'] = zhangs_rule(rules_2)

# Set the lower bound for Zhang's rule to 0.8
rules_2 = rules_2[rules_2['zhang'] > 0.8].sort_values('zhang',ascending=False)
rules_2
# Out:
# /usr/local/lib/python3.8/dist-packages/mlxtend/frequent_patterns/association_rules.py:105: RuntimeWarning: invalid value encountered in double_scalars
#   "confidence": lambda sAC, sA, _: sAC/sA,
# /usr/local/lib/python3.8/dist-packages/mlxtend/frequent_patterns/association_rules.py:106: RuntimeWarning: invalid value encountered in double_scalars
#   "lift": lambda sAC, sA, sC: metric_dict["confidence"](sAC, sA, sC)/sC,
#      antecedents consequents  antecedent support  consequent support  \
# 270         (10)        (15)            0.018158            0.014844
# 271         (15)        (10)            0.014844            0.018158
# 520        (173)       (172)            0.017222            0.010304
# 521        (172)       (173)            0.010304            0.017222
# 122        (169)        (15)            0.128116            0.014844
# 360        (171)       (173)            0.027165            0.017222
# 361        (173)       (171)            0.017222            0.027165
# 948         (10)         (1)            0.018158            0.011529
# 949          (1)        (10)            0.011529            0.018158
# 822        (171)       (172)            0.027165            0.010304
# 823        (172)       (171)            0.010304            0.027165
# 655        (112)  (130, 105)            0.026733            0.014267
# 1480  (105, 130)         (1)            0.014267            0.011529
# 654   (130, 105)       (112)            0.014267            0.026733
# 1481         (1)  (105, 130)            0.011529            0.014267
# 1576        (15)  (169, 105)            0.014844            0.011745
# 1573  (169, 105)        (15)            0.011745            0.014844
# 1204  (169, 130)        (15)            0.016069            0.014844
# 560        (112)   (53, 130)            0.026733            0.019167
# 1207        (15)  (169, 130)            0.014844            0.016069
# 514        (112)   (54, 105)            0.026733            0.020752
#
#        support  confidence       lift  leverage  conviction     zhang
# 270   0.004395    0.242063  16.307559  0.004126    1.299787  0.956039
# 271   0.004395    0.296117  16.307559  0.004126    1.394892  0.952822
# 520   0.002522    0.146444  14.212189  0.002345    1.159497  0.945928
# 521   0.002522    0.244755  14.212189  0.002345    1.301272  0.939317
# 122   0.008503    0.066367   4.471054  0.006601    1.055186  0.890416
# 360   0.003459    0.127321   7.393139  0.002991    1.126163  0.888886
# 361   0.003459    0.200837   7.393139  0.002991    1.217317  0.879893
# 948   0.001441    0.079365   6.883929  0.001232    1.073684  0.870542
# 949   0.001441    0.125000   6.883929  0.001232    1.122105  0.864703
# 822   0.001729    0.063660   6.178183  0.001449    1.056984  0.861544
# 823   0.001729    0.167832   6.178183  0.001449    1.169037  0.846866
# 655   0.002162    0.080863   5.667728  0.001780    1.072454  0.846183
# 1480  0.000937    0.065657   5.694886  0.000772    1.057931  0.836336
# 654   0.002162    0.151515   5.667728  0.001780    1.147065  0.835482
# 1481  0.000937    0.081250   5.694886  0.000772    1.072906  0.834019
# 1576  0.000865    0.058252   4.959676  0.000690    1.049384  0.810403
# 1573  0.000865    0.073620   4.959676  0.000690    1.063447  0.807862
# 1204  0.001153    0.071749   4.833645  0.000914    1.061304  0.806069
# 560   0.002378    0.088949   4.640719  0.001865    1.076595  0.806065
# 1207  0.001153    0.077670   4.833645  0.000914    1.066789  0.805067
# 514   0.002522    0.094340   4.545991  0.001967    1.081253  0.801451

# %% [markdown]
# ### Association Rule #3 - Multiple Metrics (trial from DataCamp)

# %%
# Recover association rules using a minium support threshold of 0.001
rules_3 = association_rules(frequent_itemsets, metric = 'support', min_threshold = 0.001)
rules_3['zhang'] = zhangs_rule(rules_3)

# Apply metric thresholds
rules_3 = rules_3[(rules_3['antecedent support'] > 0.002) &
                       (rules_3['consequent support'] > 0.01) &
                       (rules_3['lift'] > 2.50) &
                       (rules_3['zhang'] > 0.80)] 

# Print remaining rule
rules_3.sort_values('support',ascending=False)
# Out:
#      antecedents consequents  antecedent support  consequent support  \
# 252        (169)        (15)            0.128116            0.014844
# 552         (10)        (15)            0.018158            0.014844
# 553         (15)        (10)            0.014844            0.018158
# 690        (171)       (173)            0.027165            0.017222
# 691        (173)       (171)            0.017222            0.027165
# 835         (42)       (171)            0.009728            0.027165
# 936        (112)   (54, 105)            0.026733            0.020752
# 952        (173)       (172)            0.017222            0.010304
# 953        (172)       (173)            0.010304            0.017222
# 1022       (112)   (53, 130)            0.026733            0.019167
# 1079       (224)       (156)            0.007422            0.010592
# 1150  (130, 105)       (112)            0.014267            0.026733
# 1151       (112)  (130, 105)            0.026733            0.014267
# 1458       (171)       (172)            0.027165            0.010304
# 1459       (172)       (171)            0.010304            0.027165
# 1495       (152)       (156)            0.007278            0.010592
# 1652        (10)         (1)            0.018158            0.011529
# 1653         (1)        (10)            0.011529            0.018158
# 1696  (169, 215)        (48)            0.006989            0.030408
# 1744   (53, 131)       (171)            0.007782            0.027165
# 1870        (42)       (172)            0.009728            0.010304
# 1879       (128)       (124)            0.006053            0.021185
# 1898   (10, 169)        (15)            0.006341            0.014844
# 1900   (169, 15)        (10)            0.008503            0.018158
# 2077  (169, 130)        (15)            0.016069            0.014844
# 2080        (15)  (169, 130)            0.014844            0.016069
# 2283  (170, 105)       (112)            0.005548            0.026733
# 2304  (112, 105)         (1)            0.006341            0.011529
# 2364   (171, 54)       (112)            0.004251            0.026733
# 2366   (54, 112)       (171)            0.005620            0.027165
#
#        support  confidence       lift  leverage  conviction     zhang
# 252   0.008503    0.066367   4.471054  0.006601    1.055186  0.890416
# 552   0.004395    0.242063  16.307559  0.004126    1.299787  0.956039
# 553   0.004395    0.296117  16.307559  0.004126    1.394892  0.952822
# 690   0.003459    0.127321   7.393139  0.002991    1.126163  0.888886
# 691   0.003459    0.200837   7.393139  0.002991    1.217317  0.879893
# 835   0.002882    0.296296  10.907162  0.002618    1.382449  0.917240
# 936   0.002522    0.094340   4.545991  0.001967    1.081253  0.801451
# 952   0.002522    0.146444  14.212189  0.002345    1.159497  0.945928
# 953   0.002522    0.244755  14.212189  0.002345    1.301272  0.939317
# 1022  0.002378    0.088949   4.640719  0.001865    1.076595  0.806065
# 1079  0.002306    0.310680  29.330691  0.002227    1.435338  0.973128
# 1150  0.002162    0.151515   5.667728  0.001780    1.147065  0.835482
# 1151  0.002162    0.080863   5.667728  0.001780    1.072454  0.846183
# 1458  0.001729    0.063660   6.178183  0.001449    1.056984  0.861544
# 1459  0.001729    0.167832   6.178183  0.001449    1.169037  0.846866
# 1495  0.001657    0.227723  21.498889  0.001580    1.281156  0.960476
# 1652  0.001441    0.079365   6.883929  0.001232    1.073684  0.870542
# 1653  0.001441    0.125000   6.883929  0.001232    1.122105  0.864703
# 1696  0.001441    0.206186   6.780671  0.001229    1.221434  0.858523
# 1744  0.001441    0.185185   6.816976  0.001230    1.193933  0.860000
# 1870  0.001297    0.133333  12.939860  0.001197    1.141957  0.931783
# 1879  0.001297    0.214286  10.115160  0.001169    1.245765  0.906626
# 1898  0.001297    0.204545  13.780009  0.001203    1.238482  0.933349
# 1900  0.001297    0.152542   8.400726  0.001143    1.158573  0.888517
# 2077  0.001153    0.071749   4.833645  0.000914    1.061304  0.806069
# 2080  0.001153    0.077670   4.833645  0.000914    1.066789  0.805067
# 2283  0.001009    0.181818   6.801274  0.000860    1.189549  0.857728
# 2304  0.001009    0.159091  13.799148  0.000936    1.175479  0.933451
# 2364  0.001009    0.237288   8.876239  0.000895    1.276061  0.891128
# 2366  0.001009    0.179487   6.607223  0.000856    1.185642  0.853447

# %% [markdown]
# ### Association Rule #4 - Lift & Zhang

# %%
# Recover association rules using a minium support threshold of 0.001
rules_4 = association_rules(frequent_itemsets, metric = 'support', min_threshold = 0.001)
rules_4['zhang'] = zhangs_rule(rules_4)

# Apply metric thresholds
rules_4 = rules_4[(rules_4['lift'] > 1.00) &
                  (rules_4['zhang'] > 0.50)] 

# Print remaining rule
rules_4.sort_values('zhang',ascending=False)
# Out:
#      antecedents consequents  antecedent support  consequent support  \
# 1078       (156)       (224)            0.010592            0.007422
# 2306       (112)    (1, 105)            0.026733            0.001946
# 1079       (224)       (156)            0.007422            0.010592
# 1494       (156)       (152)            0.010592            0.007278
# 2307       (105)    (1, 112)            0.099222            0.001369
# ...          ...         ...                 ...                 ...
# 2141       (215)  (104, 112)            0.081640            0.007134
# 2363       (112)   (169, 54)            0.026733            0.019311
# 1175  (167, 130)       (215)            0.013403            0.081640
# 287         (61)   (53, 215)            0.428376            0.012250
# 1440  (131, 130)       (105)            0.008791            0.099222
#
#        support  confidence       lift  leverage  conviction     zhang
# 1078  0.002306    0.217687  29.330691  0.002227    1.268774  0.976247
# 2306  0.001009    0.037736  19.396226  0.000957    1.037194  0.974495
# 1079  0.002306    0.310680  29.330691  0.002227    1.435338  0.973128
# 1494  0.001657    0.156463  21.498889  0.001580    1.176856  0.963694
# 2307  0.001009    0.010167   7.426213  0.000873    1.008888  0.960660
# ...        ...         ...        ...       ...         ...       ...
# 2141  0.001081    0.013239   1.855893  0.000498    1.006188  0.502173
# 2363  0.001009    0.037736   1.954097  0.000493    1.019147  0.501666
# 1175  0.002162    0.161290   1.975629  0.001068    1.094968  0.500540
# 287   0.007350    0.017157   1.400639  0.002102    1.004993  0.500399
# 1440  0.001729    0.196721   1.982642  0.000857    1.121377  0.500018
#
# [433 rows x 10 columns]

# %% [markdown]
# ### Association Rule #5 - Confidence & Zhang

# %%
# Recover association rules using a minium support threshold of 0.001
rules_5 = association_rules(frequent_itemsets, metric = 'support', min_threshold = 0.001)
rules_5['zhang'] = zhangs_rule(rules_5)

# Apply metric thresholds
rules_5 = rules_5[(rules_5['confidence'] > 0.20) &
                  (rules_5['zhang'] > 0.80)] 

# Print remaining rule
rules_5.sort_values('zhang',ascending=False)
# Out:
#      antecedents consequents  antecedent support  consequent support  \
# 1078       (156)       (224)            0.010592            0.007422
# 1079       (224)       (156)            0.007422            0.010592
# 1495       (152)       (156)            0.007278            0.010592
# 552         (10)        (15)            0.018158            0.014844
# 553         (15)        (10)            0.014844            0.018158
# 2303    (1, 105)       (112)            0.001946            0.026733
# 953        (172)       (173)            0.010304            0.017222
# 1898   (10, 169)        (15)            0.006341            0.014844
# 835         (42)       (171)            0.009728            0.027165
# 1879       (128)       (124)            0.006053            0.021185
# 2364   (171, 54)       (112)            0.004251            0.026733
# 691        (173)       (171)            0.017222            0.027165
# 2302    (1, 112)       (105)            0.001369            0.099222
# 1696  (169, 215)        (48)            0.006989            0.030408
# 2078   (15, 130)       (169)            0.001657            0.128116
#
#        support  confidence       lift  leverage  conviction     zhang
# 1078  0.002306    0.217687  29.330691  0.002227    1.268774  0.976247
# 1079  0.002306    0.310680  29.330691  0.002227    1.435338  0.973128
# 1495  0.001657    0.227723  21.498889  0.001580    1.281156  0.960476
# 552   0.004395    0.242063  16.307559  0.004126    1.299787  0.956039
# 553   0.004395    0.296117  16.307559  0.004126    1.394892  0.952822
# 2303  0.001009    0.518519  19.396226  0.000957    2.021401  0.950292
# 953   0.002522    0.244755  14.212189  0.002345    1.301272  0.939317
# 1898  0.001297    0.204545  13.780009  0.001203    1.238482  0.933349
# 835   0.002882    0.296296  10.907162  0.002618    1.382449  0.917240
# 1879  0.001297    0.214286  10.115160  0.001169    1.245765  0.906626
# 2364  0.001009    0.237288   8.876239  0.000895    1.276061  0.891128
# 691   0.003459    0.200837   7.393139  0.002991    1.217317  0.879893
# 2302  0.001009    0.736842   7.426213  0.000873    3.422957  0.866528
# 1696  0.001441    0.206186   6.780671  0.001229    1.221434  0.858523
# 2078  0.001153    0.695652   5.429843  0.000941    2.864760  0.817187

# %% [markdown]
# ## Plotting Rule #5

# %%
support_table = rules_5.pivot(index='consequents', columns='antecedents', values='support')

plt.figure(figsize=(15,9))
sns.heatmap(support_table,annot=True)
# Out:
# <AxesSubplot:xlabel='antecedents', ylabel='consequents'>

# %% [markdown]
# Heatmap: See association

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='antecedent support', y='consequent support', size='lift', data=rules_5)
# Out:
# <AxesSubplot:xlabel='antecedent support', ylabel='consequent support'>

# %% [markdown]
# Scatterplot
#
#
# *   Identify natural thresholds of data
# *   Use findings to prune

# %%
# Converting rules to coordinates
rules_5['antecedents'] = rules_5['antecedents'].apply(lambda antecedent: list(antecedent)[0])
rules_5['consequents'] = rules_5['consequents'].apply(lambda consequent: list(consequent)[0])
rules_5['rule'] = rules_5.index

# Define coordinates and label 
coords = rules_5[['antecedents','consequents','rule']]
coords.head()
# Out:
#     antecedents consequents  rule
# 552          10          15   552
# 553          15          10   553
# 691         173         171   691
# 835          42         171   835
# 953         172         173   953

# %%
# Generate Parallel coordinates plot
from pandas.plotting import parallel_coordinates
plt.figure(figsize=(15,9))
parallel_coordinates(coords,'rule')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # MBA - Procedures that are claimed together for a diagnosis

# %% [markdown]
# ## Preparing Basket

# %%
# Combine table of claims with combination of diagnosis with the procedures
sa_table = pd.read_excel('/content/sa_table.xlsx')

# Convert SA Code to categorical
sa_table['sacode'] = sa_table['sacode'].astype(int).astype(str)

procedures_basket = pd.merge(claims_icd, sa_table, on='sacode', how='left')
procedures_basket.head()
# Out:
#   claimcode  icdno icdcategory ICD CODE  \
# 0    203746   6127          84    G90.0
# 1    203913  40054         261      W55
# 2    205599  12286         124      K21
# 3    205779  43705         277    Z03.0
# 4    205781  43705         277    Z03.0
#
#                                   ICD DISEASE sacode  claims_icd  \
# 0  Idiopathic peripheral autonomic neuropathy   3718   203746_84
# 1                  Contact with other mammals   3747  203913_261
# 2            Gastro-esophageal reflux disease   3718  205599_124
# 3      Observation for suspected tuberculosis   3979  205779_277
# 4      Observation for suspected tuberculosis   3979  205781_277
#
#      SA DESCRIPTION    SA CATEGORY
# 0      CONSULTATION  HOSPITAL BILL
# 1    EMERGENCY ROOM  HOSPITAL BILL
# 2      CONSULTATION  HOSPITAL BILL
# 3  RADIOLOGY - XRAY  HOSPITAL BILL
# 4  RADIOLOGY - XRAY  HOSPITAL BILL

# %%
procedures_basket = procedures_basket.groupby('icdcategory').filter(lambda x : x['icdcategory'].shape[0]>1)
procedures_basket['icdcategory'].value_counts().sum()
# Out:
# 185382

# %%
procedures = procedures_basket.groupby('icdcategory').agg(lambda col: ','.join(col)).reset_index()
procedures.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/generic.py:303: FutureWarning: Dropping invalid columns in SeriesGroupBy.agg is deprecated. In a future version, a TypeError will be raised. Before calling .agg, select only columns which should be valid for the aggregating function.
#   results[key] = self.aggregate(func)
#   icdcategory                                          claimcode  \
# 0           1  213151,213785,214013,218616,219828,220599,2232...
# 1          10  210939,210956,211089,211104,211431,213099,2131...
# 2         100  207518,208629,212772,215674,216818,216819,2169...
# 3         101                                      345874,425423
# 4         102  245378,245379,254549,257151,260686,269259,2836...
#
#                                             ICD CODE  \
# 0  A09.0,A06.9,A06.9,A09.9,A06.9,A09.9,A06.9,A09....
# 1  A90,A90,A90,A90,A90,A90,A90,A90,A90,A90,A90,A9...
# 2  H90.42,H93.1,H93.1,H93.1,H91.9,H91.9,H91.9,H91...
# 3                                        H95.0,H95.1
# 4  I00,I00,I00,I00,I00,I00,I01.9,I00,I00,I00,I00,...
#
#                                          ICD DISEASE  \
# 0  Infectious diarrhea,Amebiasis, unspecified,Ame...
# 1  Dengue fever [classical dengue],Dengue fever [...
# 2  Sensorineural hearing loss, unilateral, left e...
# 3  Recurrent cholesteatoma of postmastoidectomy c...
# 4  Rheumatic fever without heart involvement,Rheu...
#
#                                               sacode  \
# 0  3747,3952,3812,3750,3806,3808,3812,3718,3808,3...
# 1  3821,3748,3745,3748,3808,3808,3808,3808,3808,3...
# 2  3718,3718,3828,3718,3828,3821,3828,3718,3828,3...
# 3                                          3712,3718
# 4  3816,3808,3718,3718,3800,3718,3816,3718,3718,3...
#
#                                           claims_icd
# 0  213151_1,213785_1,214013_1,218616_1,219828_1,2...
# 1  210939_10,210956_10,211089_10,211104_10,211431...
# 2  207518_100,208629_100,212772_100,215674_100,21...
# 3                              345874_101,425423_101
# 4  245378_102,245379_102,254549_102,257151_102,26...

# %%
procedures['icdcategory'].nunique()
# Out:
# 223

# %% [markdown]
# ## Preparing Transaction List

# %%
procedures['sa'] = procedures['sacode'].apply(lambda t: t.split(','))
procedures = procedures['sa']
procedures.head()
# Out:
# 0    [3747, 3952, 3812, 3750, 3806, 3808, 3812, 371...
# 1    [3821, 3748, 3745, 3748, 3808, 3808, 3808, 380...
# 2    [3718, 3718, 3828, 3718, 3828, 3821, 3828, 371...
# 3                                         [3712, 3718]
# 4    [3816, 3808, 3718, 3718, 3800, 3718, 3816, 371...
# Name: sa, dtype: object

# %%
procedures_list = list(procedures)

# %% [markdown]
# ## One Hot Encoding

# %%
# Instantiate transaction encoder and identify unique items in transactions
encoder = TransactionEncoder().fit(procedures_list)

# One-hot encode transactions
onehot = encoder.transform(procedures_list)

# Convert one-hot encoded data to DataFrame
onehot = pd.DataFrame(onehot, columns = encoder.columns_)
onehot
# Out:
#          0   1195   1196   1197   1199   1201   1203   1243   1246   1251  \
# 0     True  False   True   True  False  False  False  False  False  False
# 1    False   True   True   True  False  False   True  False  False  False
# 2     True  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 218   True  False  False  False  False  False  False  False  False  False
# 219  False  False  False  False  False  False  False  False  False  False
# 220   True  False  False  False  False  False  False  False  False   True
# 221   True  False  False  False  False  False  False  False  False   True
# 222   True  False   True   True  False  False  False  False  False   True
#
#      ...   4123   4124   4125   4129   4195   4196   4201   4202   4209   4215
# 0    ...  False  False  False  False  False  False  False  False  False  False
# 1    ...  False  False  False  False  False  False  False  False  False  False
# 2    ...  False   True  False  False  False  False  False  False  False  False
# 3    ...  False  False  False  False  False  False  False  False  False  False
# 4    ...  False  False  False  False  False  False  False  False  False  False
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 218  ...  False  False  False  False  False  False  False  False  False  False
# 219  ...  False  False  False  False  False  False  False  False  False  False
# 220  ...   True   True  False  False  False  False  False  False  False  False
# 221  ...  False   True  False  False  False  False  False  False  False  False
# 222  ...  False  False  False  False  False  False  False  False  False  False
#
# [223 rows x 291 columns]

# %% [markdown]
# ## Apriori

# %%
# Choose max_len
procedures_basket['icdcategory'].value_counts().describe()
# Out:
# count      223.000000
# mean       831.309417
# std       2578.298545
# min          2.000000
# 25%         17.500000
# 50%        133.000000
# 75%        553.000000
# max      26171.000000
# Name: icdcategory, dtype: float64

# %%
procedure_count = pd.DataFrame(procedures_basket['icdcategory'].value_counts())

plt.figure(figsize=(5,8))
ax = sns.boxplot(y='icdcategory', data=procedure_count)
ax.set_ylabel('Number of procedures per ICD category')
# Out:
# Text(0, 0.5, 'Number of procedures per ICD category')

# %%
# Getting combinations of procedure sets
frequent_proceduresets = apriori(onehot, 
                            min_support = 0.1, 
                            max_len = 4, 
                            use_colnames = True).sort_values('support',ascending=False)
frequent_proceduresets.head()
# Out:
#        support      itemsets
# 92    0.950673        (3718)
# 119   0.632287        (3803)
# 123   0.632287        (3808)
# 8712  0.632287  (3803, 3718)
# 8716  0.627803  (3808, 3718)

# %%
# Recover association rules using a minium support threshold of 0.001
procedure_rules = association_rules(frequent_proceduresets, metric = 'support', min_threshold = 0.01)
procedure_rules['zhang'] = zhangs_rule(procedure_rules)

# Apply metric thresholds
procedure_rules = procedure_rules[(procedure_rules['confidence'] > 0.50) &
                  (procedure_rules['zhang'] > 0.65)] 

# Print remaining rule
procedure_rules.sort_values('zhang',ascending=False)
# Out:
#                 antecedents   consequents  antecedent support  \
# 6                    (3718)        (4092)            0.950673
# 46                   (3718)  (3808, 4092)            0.950673
# 38                   (3718)  (3808, 3979)            0.950673
# 22                   (3718)        (3978)            0.950673
# 30                   (3718)  (3803, 3979)            0.950673
# ...                     ...           ...                 ...
# 1347918        (3629, 3952)  (3750, 1251)            0.125561
# 1411633  (3718, 1251, 1195)        (4124)            0.125561
# 1411639        (1251, 1195)  (4124, 3718)            0.125561
# 1379812  (3988, 3802, 3961)        (4124)            0.125561
# 1465327        (4123, 3991)  (3747, 3802)            0.125561
#
#          consequent support   support  confidence      lift  leverage  \
# 6                  0.569507  0.569507    0.599057  1.051887  0.028092
# 46                 0.488789  0.488789    0.514151  1.051887  0.024111
# 38                 0.511211  0.511211    0.537736  1.051887  0.025217
# 22                 0.538117  0.538117    0.566038  1.051887  0.026544
# 30                 0.515695  0.515695    0.542453  1.051887  0.025438
# ...                     ...       ...         ...       ...       ...
# 1347918            0.246637  0.071749    0.571429  2.316883  0.040781
# 1411633            0.246637  0.071749    0.571429  2.316883  0.040781
# 1411639            0.246637  0.071749    0.571429  2.316883  0.040781
# 1379812            0.246637  0.071749    0.571429  2.316883  0.040781
# 1465327            0.246637  0.071749    0.571429  2.316883  0.040781
#
#          conviction  zhang
# 6          1.073701   1.00
# 46         1.052201   1.00
# 38         1.057381   1.00
# 22         1.064340   1.00
# 30         1.058481   1.00
# ...             ...    ...
# 1347918    1.757848   0.65
# 1411633    1.757848   0.65
# 1411639    1.757848   0.65
# 1379812    1.757848   0.65
# 1465327    1.757848   0.65
#
# [2245475 rows x 10 columns]

# %%
# Getting combinations of procedure sets
frequent_proceduresets_2 = apriori(onehot, 
                            min_support = 0.1, 
                            max_len = 5, 
                            use_colnames = True).sort_values('support',ascending=False)
frequent_proceduresets_2.head()
# Out:
#       support      itemsets
# 13   0.950673        (3718)
# 26   0.632287        (3808)
# 426  0.632287  (3803, 3718)
# 23   0.632287        (3803)
# 429  0.627803  (3808, 3718)

# %%
# Recover association rules using a minium support threshold of 0.001
procedure_rules_2 = association_rules(frequent_proceduresets_2, metric = 'support', min_threshold = 0.01)
procedure_rules_2['zhang'] = zhangs_rule(procedure_rules_2)

# Apply metric thresholds
procedure_rules_2 = procedure_rules_2[(procedure_rules_2['confidence'] > 0.50) &
                  (procedure_rules_2['zhang'] > 0.65)] 

# Print remaining rule
procedure_rules_2.sort_values('zhang',ascending=False)
# Out:
#                  antecedents   consequents  antecedent support  \
# 8                     (3718)        (4092)            0.950673
# 36                    (3718)  (3808, 3979)            0.950673
# 44                    (3718)  (3808, 4092)            0.950673
# 22                    (3718)        (3978)            0.950673
# 30                    (3718)  (3803, 3979)            0.950673
# ...                      ...           ...                 ...
# 93210     (3803, 3807, 3821)  (3747, 3979)            0.282511
# 90510     (4020, 4092, 3712)        (1251)            0.282511
# 92692           (3989, 3808)        (1251)            0.282511
# 90855  (3803, 3979, 4020, 0)        (1251)            0.282511
# 94854  (4020, 3718, 3979, 0)        (1251)            0.282511
#
#        consequent support   support  confidence      lift  leverage  \
# 8                0.569507  0.569507    0.599057  1.051887  0.028092
# 36               0.511211  0.511211    0.537736  1.051887  0.025217
# 44               0.488789  0.488789    0.514151  1.051887  0.024111
# 22               0.538117  0.538117    0.566038  1.051887  0.026544
# 30               0.515695  0.515695    0.542453  1.051887  0.025438
# ...                   ...       ...         ...       ...       ...
# 93210            0.457399  0.242152    0.857143  1.873950  0.112932
# 90510            0.457399  0.242152    0.857143  1.873950  0.112932
# 92692            0.457399  0.242152    0.857143  1.873950  0.112932
# 90855            0.457399  0.242152    0.857143  1.873950  0.112932
# 94854            0.457399  0.242152    0.857143  1.873950  0.112932
#
#        conviction  zhang
# 8        1.073701   1.00
# 36       1.057381   1.00
# 44       1.052201   1.00
# 22       1.064340   1.00
# 30       1.058481   1.00
# ...           ...    ...
# 93210    3.798206   0.65
# 90510    3.798206   0.65
# 92692    3.798206   0.65
# 90855    3.798206   0.65
# 94854    3.798206   0.65
#
# [3028556 rows x 10 columns]

# %% [markdown]
# ## Based on Rule #5

# %%
procedures_trial = pd.merge(transactions, sa_table, on='sacode', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-0dda40803fcb> in <module>
# ----> 1 procedures_trial = pd.merge(transactions, sa_table, on='sacode', how='left')
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
#     701         # validate the merge keys dtypes. We may need to coerce
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1107                         right_keys.append(rk)
#    1108                     if lk is not None:
# -> 1109                         left_keys.append(left._get_label_or_level_values(lk))
#    1110                         join_names.append(lk)
#    1111                     else:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'sacode'

# %%
# Create an array for the index of the rules generated in Association Rule
rules_5_basket = rules_5.index
rules_5_basket

# %%
procedures_trial = procedures_trial.iloc[rules_5_basket]
procedures_trial
